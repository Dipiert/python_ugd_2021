# %% [markdown]
# # Space Age
#
# Given an age in seconds, calculate how old someone would be on:
#
#     Earth: orbital period 365.25 Earth days, or 31557600 seconds
#     Mercury: orbital period 0.2408467 Earth years
#     Venus: orbital period 0.61519726 Earth years
#     Mars: orbital period 1.8808158 Earth years
#     Jupiter: orbital period 11.862615 Earth years
#     Saturn: orbital period 29.447498 Earth years
#     Uranus: orbital period 84.016846 Earth years
#     Neptune: orbital period 164.79132 Earth years
#
# So if you were told someone were 1,000,000,000 seconds old, you should be able to say that they're 31.69 Earth-years old.

# %%
class SpaceAgeTest(unittest.TestCase):

    def test_age_on_earth(self):
        self.assertEqual(SpaceAge(1000000000).on_earth(), 31.69)
    
    def test_age_on_mercury(self):
        self.assertEqual(SpaceAge(2134835688).on_mercury(), 280.88)

    def test_age_on_venus(self):
        self.assertEqual(SpaceAge(189839836).on_venus(), 9.78)

    def test_age_on_mars(self):
        self.assertEqual(SpaceAge(2129871239).on_mars(), 35.88)

    def test_age_on_jupiter(self):
        self.assertEqual(SpaceAge(901876382).on_jupiter(), 2.41)

    def test_age_on_saturn(self):
        self.assertEqual(SpaceAge(2000000000).on_saturn(), 2.15)

    def test_age_on_uranus(self):
        self.assertEqual(SpaceAge(1210123456).on_uranus(), 0.46)

    def test_age_on_neptune(self):
        self.assertEqual(SpaceAge(1821023456).on_neptune(), 0.35)


unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ........
# ----------------------------------------------------------------------
# Ran 8 tests in 0.032s
#
# OK

# %% [markdown]
# Given a number, find the sum of all the unique multiples of particular numbers up to but not including that number.
#
# If we list all the natural numbers below 20 that are multiples of 3 or 5, we get 3, 5, 6, 9, 10, 12, 15, and 18.
#
# The sum of these multiples is 78.
#
# You can make the following assumptions about the inputs to the sum_of_multiples function:
#
#     All input numbers are non-negative ints, i.e. natural numbers including zero.
#     A list of factors must be given, and its elements are unique and sorted in ascending order.

# %%
import unittest


class SumOfMultiplesTest(unittest.TestCase):
    def test_no_multiples_within_limit(self):
        self.assertEqual(sum_of_multiples(1, [3, 5]), 0)

    def test_one_factor_has_multiples_within_limit(self):
        self.assertEqual(sum_of_multiples(4, [3, 5]), 3)

    def test_more_than_one_multiple_within_limit(self):
        self.assertEqual(sum_of_multiples(7, [3]), 9)

    def test_more_than_one_factor_with_multiples_within_limit(self):
        self.assertEqual(sum_of_multiples(10, [3, 5]), 23)

    def test_each_multiple_is_only_counted_once(self):
        self.assertEqual(sum_of_multiples(100, [3, 5]), 2318)

    def test_a_much_larger_limit(self):
        self.assertEqual(sum_of_multiples(1000, [3, 5]), 233168)

    def test_three_factors(self):
        self.assertEqual(sum_of_multiples(20, [7, 13, 17]), 51)

    def test_factors_not_relatively_prime(self):
        self.assertEqual(sum_of_multiples(15, [4, 6]), 30)

    def test_some_pairs_of_factors_relatively_prime_and_some_not(self):
        self.assertEqual(sum_of_multiples(150, [5, 6, 8]), 4419)

    def test_one_factor_is_a_multiple_of_another(self):
        self.assertEqual(sum_of_multiples(51, [5, 25]), 275)

    def test_much_larger_factors(self):
        self.assertEqual(sum_of_multiples(10000, [43, 47]), 2203160)

    def test_all_numbers_are_multiples_of_1(self):
        self.assertEqual(sum_of_multiples(100, [1]), 4950)

    def test_no_factors_means_an_empty_sum(self):
        self.assertEqual(sum_of_multiples(10000, []), 0)

    def test_the_only_multiple_of_0_is_0(self):
        self.assertEqual(sum_of_multiples(1, [0]), 0)

    def test_the_factor_0_does_not_affect_the_sum_of_multiples_of_other_factors(self):
        self.assertEqual(sum_of_multiples(4, [3, 0]), 3)

    def test_solutions_using_include_exclude_must_extend_to_cardinality_greater_than_3(
        self
    ):
        self.assertEqual(sum_of_multiples(10000, [2, 3, 5, 7, 11]), 39614537)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ........EEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: test_a_much_larger_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 21, in test_a_much_larger_limit
#     self.assertEqual(sum_of_multiples(1000, [3, 5]), 233168)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_all_numbers_are_multiples_of_1 (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 39, in test_all_numbers_are_multiples_of_1
#     self.assertEqual(sum_of_multiples(100, [1]), 4950)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_each_multiple_is_only_counted_once (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 18, in test_each_multiple_is_only_counted_once
#     self.assertEqual(sum_of_multiples(100, [3, 5]), 2318)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_factors_not_relatively_prime (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 27, in test_factors_not_relatively_prime
#     self.assertEqual(sum_of_multiples(15, [4, 6]), 30)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_more_than_one_factor_with_multiples_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 15, in test_more_than_one_factor_with_multiples_within_limit
#     self.assertEqual(sum_of_multiples(10, [3, 5]), 23)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_more_than_one_multiple_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 12, in test_more_than_one_multiple_within_limit
#     self.assertEqual(sum_of_multiples(7, [3]), 9)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_much_larger_factors (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 36, in test_much_larger_factors
#     self.assertEqual(sum_of_multiples(10000, [43, 47]), 2203160)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_no_factors_means_an_empty_sum (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 42, in test_no_factors_means_an_empty_sum
#     self.assertEqual(sum_of_multiples(10000, []), 0)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_no_multiples_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 6, in test_no_multiples_within_limit
#     self.assertEqual(sum_of_multiples(1, [3, 5]), 0)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_one_factor_has_multiples_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 9, in test_one_factor_has_multiples_within_limit
#     self.assertEqual(sum_of_multiples(4, [3, 5]), 3)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_one_factor_is_a_multiple_of_another (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 33, in test_one_factor_is_a_multiple_of_another
#     self.assertEqual(sum_of_multiples(51, [5, 25]), 275)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_solutions_using_include_exclude_must_extend_to_cardinality_greater_than_3 (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 53, in test_solutions_using_include_exclude_must_extend_to_cardinality_greater_than_3
#     self.assertEqual(sum_of_multiples(10000, [2, 3, 5, 7, 11]), 39614537)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_some_pairs_of_factors_relatively_prime_and_some_not (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 30, in test_some_pairs_of_factors_relatively_prime_and_some_not
#     self.assertEqual(sum_of_multiples(150, [5, 6, 8]), 4419)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_the_factor_0_does_not_affect_the_sum_of_multiples_of_other_factors (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 48, in test_the_factor_0_does_not_affect_the_sum_of_multiples_of_other_factors
#     self.assertEqual(sum_of_multiples(4, [3, 0]), 3)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_the_only_multiple_of_0_is_0 (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 45, in test_the_only_multiple_of_0_is_0
#     self.assertEqual(sum_of_multiples(1, [0]), 0)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_three_factors (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 24, in test_three_factors
#     self.assertEqual(sum_of_multiples(20, [7, 13, 17]), 51)
# NameError: name 'sum_of_multiples' is not defined
#
# ----------------------------------------------------------------------
# Ran 24 tests in 0.041s
#
# FAILED (errors=16)

# %% [markdown]
# Calculate the number of grains of wheat on a chessboard given that the number on each square doubles.
#
# There once was a wise servant who saved the life of a prince. The king promised to pay whatever the servant could dream up. Knowing that the king loved chess, the servant told the king he would like to have grains of wheat. One grain on the first square of a chess board. Two grains on the next. Four on the third, and so on.
#
# There are 64 squares on a chessboard.
#
# Write code that shows:
#
#     how many grains were on each square, and
#     the total number of grains
#
# For bonus points
#
# Did you get the tests passing and the code clean? If you want to, these are some additional things you could try:
#
#     Optimize for speed.
#     Optimize for readability.

# %%
import unittest


class GrainsTest(unittest.TestCase):

    def test_1(self):
        self.assertEqual(square(1), 1)

    def test_2(self):
        self.assertEqual(square(2), 2)

    def test_3(self):
        self.assertEqual(square(3), 4)

    def test_4(self):
        self.assertEqual(square(4), 8)

    def test_16(self):
        self.assertEqual(square(16), 32768)

    def test_32(self):
        self.assertEqual(square(32), 2147483648)

    def test_64(self):
        self.assertEqual(square(64), 9223372036854775808)

    def test_square_0_raises_an_exception(self):
        with self.assertRaisesWithMessage(ValueError):
            square(0)

    def test_negative_square_raises_an_exception(self):
        with self.assertRaisesWithMessage(ValueError):
            square(-1)

    def test_square_greater_than_64_raises_an_exception(self):
        with self.assertRaisesWithMessage(ValueError):
            square(65)

    def test_returns_the_total_number_of_grains_on_the_board(self):
        self.assertEqual(total(), 18446744073709551615)

    # Utility functions
    def assertRaisesWithMessage(self, exception):
        return self.assertRaisesRegex(exception, r".+")

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# EEEEEEEEEEE........EEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: test_1 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 7, in test_1
#     self.assertEqual(square(1), 1)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_16 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 19, in test_16
#     self.assertEqual(square(16), 32768)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_2 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 10, in test_2
#     self.assertEqual(square(2), 2)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_3 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 13, in test_3
#     self.assertEqual(square(3), 4)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_32 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 22, in test_32
#     self.assertEqual(square(32), 2147483648)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_4 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 16, in test_4
#     self.assertEqual(square(4), 8)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_64 (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 25, in test_64
#     self.assertEqual(square(64), 9223372036854775808)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_negative_square_raises_an_exception (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 33, in test_negative_square_raises_an_exception
#     square(-1)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_returns_the_total_number_of_grains_on_the_board (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 40, in test_returns_the_total_number_of_grains_on_the_board
#     self.assertEqual(total(), 18446744073709551615)
# NameError: name 'total' is not defined
#
# ======================================================================
# ERROR: test_square_0_raises_an_exception (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 29, in test_square_0_raises_an_exception
#     square(0)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_square_greater_than_64_raises_an_exception (__main__.GrainsTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-70-1e20a36f9166>", line 37, in test_square_greater_than_64_raises_an_exception
#     square(65)
# NameError: name 'square' is not defined
#
# ======================================================================
# ERROR: test_a_much_larger_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 21, in test_a_much_larger_limit
#     self.assertEqual(sum_of_multiples(1000, [3, 5]), 233168)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_all_numbers_are_multiples_of_1 (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 39, in test_all_numbers_are_multiples_of_1
#     self.assertEqual(sum_of_multiples(100, [1]), 4950)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_each_multiple_is_only_counted_once (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 18, in test_each_multiple_is_only_counted_once
#     self.assertEqual(sum_of_multiples(100, [3, 5]), 2318)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_factors_not_relatively_prime (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 27, in test_factors_not_relatively_prime
#     self.assertEqual(sum_of_multiples(15, [4, 6]), 30)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_more_than_one_factor_with_multiples_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 15, in test_more_than_one_factor_with_multiples_within_limit
#     self.assertEqual(sum_of_multiples(10, [3, 5]), 23)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_more_than_one_multiple_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 12, in test_more_than_one_multiple_within_limit
#     self.assertEqual(sum_of_multiples(7, [3]), 9)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_much_larger_factors (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 36, in test_much_larger_factors
#     self.assertEqual(sum_of_multiples(10000, [43, 47]), 2203160)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_no_factors_means_an_empty_sum (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 42, in test_no_factors_means_an_empty_sum
#     self.assertEqual(sum_of_multiples(10000, []), 0)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_no_multiples_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 6, in test_no_multiples_within_limit
#     self.assertEqual(sum_of_multiples(1, [3, 5]), 0)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_one_factor_has_multiples_within_limit (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 9, in test_one_factor_has_multiples_within_limit
#     self.assertEqual(sum_of_multiples(4, [3, 5]), 3)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_one_factor_is_a_multiple_of_another (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 33, in test_one_factor_is_a_multiple_of_another
#     self.assertEqual(sum_of_multiples(51, [5, 25]), 275)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_solutions_using_include_exclude_must_extend_to_cardinality_greater_than_3 (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 53, in test_solutions_using_include_exclude_must_extend_to_cardinality_greater_than_3
#     self.assertEqual(sum_of_multiples(10000, [2, 3, 5, 7, 11]), 39614537)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_some_pairs_of_factors_relatively_prime_and_some_not (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 30, in test_some_pairs_of_factors_relatively_prime_and_some_not
#     self.assertEqual(sum_of_multiples(150, [5, 6, 8]), 4419)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_the_factor_0_does_not_affect_the_sum_of_multiples_of_other_factors (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 48, in test_the_factor_0_does_not_affect_the_sum_of_multiples_of_other_factors
#     self.assertEqual(sum_of_multiples(4, [3, 0]), 3)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_the_only_multiple_of_0_is_0 (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 45, in test_the_only_multiple_of_0_is_0
#     self.assertEqual(sum_of_multiples(1, [0]), 0)
# NameError: name 'sum_of_multiples' is not defined
#
# ======================================================================
# ERROR: test_three_factors (__main__.SumOfMultiplesTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-01c07433b346>", line 24, in test_three_factors
#     self.assertEqual(sum_of_multiples(20, [7, 13, 17]), 51)
# NameError: name 'sum_of_multiples' is not defined
#
# ----------------------------------------------------------------------
# Ran 35 tests in 0.064s
#
# FAILED (errors=27)

# %% [markdown]
# import unittest
#
# from prime_factors import factors
#
# # Tests adapted from `problem-specifications//canonical-data.json`
#
#
# class PrimeFactorsTest(unittest.TestCase):
#     def test_no_factors(self):
#         self.assertEqual(factors(1), [])
#
#     def test_prime_number(self):
#         self.assertEqual(factors(2), [2])
#
#     def test_square_of_a_prime(self):
#         self.assertEqual(factors(9), [3, 3])
#
#     def test_cube_of_a_prime(self):
#         self.assertEqual(factors(8), [2, 2, 2])
#
#     def test_product_of_primes_and_non_primes(self):
#         self.assertEqual(factors(12), [2, 2, 3])
#
#     def test_product_of_primes(self):
#         self.assertEqual(factors(901255), [5, 17, 23, 461])
#
#     def test_factors_include_a_large_prime(self):
#         self.assertEqual(factors(93819012551), [11, 9539, 894119])
#
#
# if __name__ == "__main__":
#     unittest.main()
